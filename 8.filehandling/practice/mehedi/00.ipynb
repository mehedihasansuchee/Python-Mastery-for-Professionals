# %% [markdown]
# ### Reading a File

# %%
with open("example.txt", "r") as file:
    content = file.read()
    print(content)

# %% [markdown]
# ### Writing  a File

# %% [markdown]
# ### Appending to a File

# %% [markdown]
# ### Closing a File

# %% [markdown]
# ### File Iteration

# %% [markdown]
# ### File Management

# %% [markdown]
# Defining a class

# %%
class Enemy:
    life = 3
    energy = 10

print(Enemy.life)
print(Enemy.energy)
# Out:
# 3
# 10

# %%
class Enemy:
    life = 5
    energy = 15

print(Enemy.life)
print(Enemy.energy)
# Out:
# 5
# 15
